# %%
from PIL import Image

# %% [markdown]
# # DWS

# %%
DWS_result = Image.open("DWS.png")
DWS_result.show()
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1000x5000 at 0x7F1024117700>

# %% [markdown]
# # DWA

# %%
DWA_result = Image.open("DWA.png")
DWA_result.show()
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1000x5000 at 0x7F102417AD30>

# %% [markdown]
# # DWP

# %%
DWP_result = Image.open("DWP.png")
DWP_result.show()
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1000x5000 at 0x7F101C130910>

# %% [markdown]
# # Correlation

# %%
real_Corr_result = Image.open("real_Corr.png")
real_Corr_result.show()
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1786x2056 at 0x7F101C1302B0>

# %%
syn_Corr_result = Image.open("syn_Corr.png")

syn_Corr_result.show()
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1000x5000 at 0x7F101C130BB0>
