# %%
from PIL import Image

# %% [markdown]
# # DWS

# %%
DWS_result = Image.open("DWS.png")
DWS_result.show()
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1000x5000 at 0x7FE264B67D90>
