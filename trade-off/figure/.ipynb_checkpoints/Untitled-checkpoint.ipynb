# %%
from PIL import Image

# %% [markdown]
# # Trade-off

# %%
trade_off_result = Image.open("trade_off.png")

trade_off_result.show()
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1713x1711 at 0x7F663C4B6A00>
