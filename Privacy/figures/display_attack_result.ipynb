# %%
from PIL import Image

# %% [markdown]
# # FBA

# %%
FBA_result = Image.open("FBA.png")

FBA_result.show()
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1000x500 at 0x7F826C160C10>

# %% [markdown]
# # PBA

# %%
PBA_result = Image.open("PBA.png")
PBA_result.show()
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1000x500 at 0x7F826C09DBB0>

# %% [markdown]
# # WGA

# %%
WGA_result = Image.open("WGA.png")
WGA_result.show()
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1000x500 at 0x7F826C2340D0>

# %% [markdown]
# # WDA

# %%
WDA_result = Image.open("WDA.png")

WDA_result.show()
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1000x500 at 0x7F826C234B80>
